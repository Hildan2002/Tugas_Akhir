# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, regularizers
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.densenet import DenseNet201, preprocess_input
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.utils import class_weight

from sklearn.metrics import classification_report, confusion_matrix
import zipfile, os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report


print(tf.__version__)
# Out:
# 2.10.1

# %%
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    print("Available GPUs:", len(gpus))
else:
    print("No GPUs available.")
# Out:
# Available GPUs: 1

# %%
base_dir = 'chest'
train_dir = 'chest/train'
test_dir = 'chest/test'
val_dir = 'chest/val'
os.listdir(base_dir)
# Out:
# ['test', 'train', 'val']

# %%
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

# Function to preview images directly from a directory
def preview_images_from_directory(directory, class_labels, num_images=5):
    class_names = os.listdir(directory)

    plt.figure(figsize=(15, 3))
    for class_name in class_names:
        class_path = os.path.join(directory, class_name)
        image_files = [f for f in os.listdir(class_path) if f.endswith('.jpeg')]
        selected_images = random.sample(image_files, min(num_images, len(image_files)))

        for i, image_file in enumerate(selected_images):
            plt.subplot(len(class_names), num_images, len(class_names) * i + class_names.index(class_name) + 1)
            img_path = os.path.join(class_path, image_file)
            img = mpimg.imread(img_path)
            plt.imshow(img)
            plt.title(f"Label: {class_labels[class_names.index(class_name)]}")
            plt.axis('off')

    plt.show()

# Define class labels for binary classification
class_labels_binary = ["Normal", "Pneumonia"]

# Preview images from the training directory
print("Preview of Training Images:")
preview_images_from_directory(train_dir, class_labels_binary)

# Preview images from the validation directory
print("Preview of Validation Images:")
preview_images_from_directory(val_dir, class_labels_binary)
# Out:
# Preview of Training Images:
# Preview of Validation Images:

# %%
img_width, img_height = 224, 224
batch_size = 128

datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    shear_range=0.2,
    zoom_range=0.2,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
)

train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
)

valid_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

val_generator = valid_datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
)
# Out:
# Found 4204 images belonging to 2 classes.
# Found 1052 images belonging to 2 classes.

# %%
# Function to preview images from a data generator with class labels
def preview_images(generator, class_labels, num_images=5):
    # Get a batch of images and labels from the generator
    images, labels = next(generator)

    # Map numeric labels to class names
    class_names = [class_labels[int(label)] for label in labels]

    # Display the images with labels
    plt.figure(figsize=(15, 3))
    for i in range(num_images):
        plt.subplot(1, num_images, i+1)
        plt.imshow(images[i])
        plt.title(f"Label: {class_names[i]}")
        plt.axis('off')
    plt.show()

# Define class labels for binary classification
class_labels_binary = ["Normal", "Pneumonia"]

# Preview images from the training generator
print("Preview of Training Images:")
preview_images(train_generator, class_labels_binary)

# Preview images from the validation generator
print("Preview of Validation Images:")
preview_images(val_generator, class_labels_binary)
# Out:
# Preview of Training Images:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Preview of Validation Images:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Display the number of samples in each set
print("Number of samples in training set:", len(train_generator.classes))
print("Number of samples in validation set:", len(val_generator.classes))

# Visualize the number of samples in each set with a bar chart
sets = ['Training', 'Validation']
counts = [len(train_generator.classes), len(val_generator.classes)]

plt.bar(sets, counts, color=['blue', 'orange'])
plt.xlabel('Data Sets')
plt.ylabel('Number of Samples')
plt.title('Number of Samples in Each Data Set')
plt.show()
# Out:
# Number of samples in training set: 4204
# Number of samples in validation set: 1052

# %%
# Display the number of samples in each class within the training set
train_class_counts = np.bincount(train_generator.classes)
train_class_labels = ['Normal', 'Pneumonia']

plt.bar(train_class_labels, train_class_counts[:len(train_class_labels)], color=['skyblue', 'navy'])
plt.xlabel('Class Labels')
plt.ylabel('Number of Samples')
plt.title('Number of Samples in Each Class (Training Set)')
plt.show()

# Display the number of samples in each class within the validation set
val_class_counts = np.bincount(val_generator.classes)
val_class_labels = ['Normal', 'Pneumonia']

plt.bar(val_class_labels, val_class_counts[:len(val_class_labels)], color=['lightcoral', 'darkred'])
plt.xlabel('Class Labels')
plt.ylabel('Number of Samples')
plt.title('Number of Samples in Each Class (Validation Set)')
plt.show()

# %%
class_weights = class_weight.compute_class_weight('balanced', classes = np.unique(train_generator.classes), y = train_generator.classes)

class_weight_dict = dict(enumerate(class_weights))

class_weight_dict
# Out:
# {0: 2.0487329434697856, 1: 0.6614222781623663}

# %%
densenet201 = DenseNet201(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet'
)

for layer in densenet201.layers:
    layer.trainable = False

x = densenet201.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = layers.Dropout(0.4)(x)
pred = layers.Dense(1, activation='sigmoid')(x)

model = Model(inputs=densenet201.input, outputs=pred)

model.compile(optimizer=tf.keras.optimizers.Adamax(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['binary_accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, min_lr=1e-5, verbose=1)

model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_binary_accuracy', save_best_only=True, mode='max', verbose=1)

# %%
epochs=50

hist = model.fit(train_generator,
                 epochs=epochs,
                 validation_data=val_generator,
                 # callbacks=[reduce_lr],
                 callbacks=[early_stopping, reduce_lr, model_checkpoint],
                 class_weight=class_weight_dict
)
# Out:
# Epoch 1/50
# 33/33 [==============================] - ETA: 0s - loss: 3.2249 - binary_accuracy: 0.7935
# Epoch 1: val_binary_accuracy improved from -inf to 0.83555, saving model to best_model.h5
# 33/33 [==============================] - 92s 2s/step - loss: 3.2249 - binary_accuracy: 0.7935 - val_loss: 2.0514 - val_binary_accuracy: 0.8356 - lr: 0.0010
# Epoch 2/50
# 33/33 [==============================] - ETA: 0s - loss: 1.6341 - binary_accuracy: 0.8711
# Epoch 2: val_binary_accuracy improved from 0.83555 to 0.87738, saving model to best_model.h5
# 33/33 [==============================] - 77s 2s/step - loss: 1.6341 - binary_accuracy: 0.8711 - val_loss: 1.3944 - val_binary_accuracy: 0.8774 - lr: 0.0010
# Epoch 3/50
# 33/33 [==============================] - ETA: 0s - loss: 1.2429 - binary_accuracy: 0.9018
# Epoch 3: val_binary_accuracy improved from 0.87738 to 0.89354, saving model to best_model.h5
# 33/33 [==============================] - 76s 2s/step - loss: 1.2429 - binary_accuracy: 0.9018 - val_loss: 1.1582 - val_binary_accuracy: 0.8935 - lr: 0.0010
# Epoch 4/50
# 33/33 [==============================] - ETA: 0s - loss: 1.0889 - binary_accuracy: 0.9049
# Epoch 4: val_binary_accuracy did not improve from 0.89354
# 33/33 [==============================] - 75s 2s/step - loss: 1.0889 - binary_accuracy: 0.9049 - val_loss: 1.0717 - val_binary_accuracy: 0.8764 - lr: 0.0010
# Epoch 5/50
# 33/33 [==============================] - ETA: 0s - loss: 0.9634 - binary_accuracy: 0.9106
# Epoch 5: val_binary_accuracy did not improve from 0.89354
# 33/33 [==============================] - 76s 2s/step - loss: 0.9634 - binary_accuracy: 0.9106 - val_loss: 0.9564 - val_binary_accuracy: 0.8859 - lr: 0.0010
# Epoch 6/50
# 33/33 [==============================] - ETA: 0s - loss: 0.8712 - binary_accuracy: 0.9184
# Epoch 6: val_binary_accuracy did not improve from 0.89354
# 33/33 [==============================] - 76s 2s/step - loss: 0.8712 - binary_accuracy: 0.9184 - val_loss: 0.9175 - val_binary_accuracy: 0.8736 - lr: 0.0010
# Epoch 7/50
# 33/33 [==============================] - ETA: 0s - loss: 0.7906 - binary_accuracy: 0.9253
# Epoch 7: val_binary_accuracy did not improve from 0.89354
# 33/33 [==============================] - 75s 2s/step - loss: 0.7906 - binary_accuracy: 0.9253 - val_loss: 0.8082 - val_binary_accuracy: 0.8935 - lr: 0.0010
# Epoch 8/50
# 33/33 [==============================] - ETA: 0s - loss: 0.7206 - binary_accuracy: 0.9320
# Epoch 8: val_binary_accuracy did not improve from 0.89354
# 33/33 [==============================] - 75s 2s/step - loss: 0.7206 - binary_accuracy: 0.9320 - val_loss: 0.7565 - val_binary_accuracy: 0.8907 - lr: 0.0010
# Epoch 9/50
# 33/33 [==============================] - ETA: 0s - loss: 0.6768 - binary_accuracy: 0.9265
# Epoch 9: val_binary_accuracy improved from 0.89354 to 0.91350, saving model to best_model.h5
# 33/33 [==============================] - 77s 2s/step - loss: 0.6768 - binary_accuracy: 0.9265 - val_loss: 0.6768 - val_binary_accuracy: 0.9135 - lr: 0.0010
# Epoch 10/50
# 33/33 [==============================] - ETA: 0s - loss: 0.6276 - binary_accuracy: 0.9277
# Epoch 10: val_binary_accuracy did not improve from 0.91350
# 33/33 [==============================] - 75s 2s/step - loss: 0.6276 - binary_accuracy: 0.9277 - val_loss: 0.6744 - val_binary_accuracy: 0.8945 - lr: 0.0010
# Epoch 11/50
# 33/33 [==============================] - ETA: 0s - loss: 0.5905 - binary_accuracy: 0.9267
# Epoch 11: val_binary_accuracy did not improve from 0.91350
# 33/33 [==============================] - 75s 2s/step - loss: 0.5905 - binary_accuracy: 0.9267 - val_loss: 0.6954 - val_binary_accuracy: 0.8698 - lr: 0.0010
# Epoch 12/50
# 33/33 [==============================] - ETA: 0s - loss: 0.5512 - binary_accuracy: 0.9329
# Epoch 12: val_binary_accuracy improved from 0.91350 to 0.91825, saving model to best_model.h5
# 33/33 [==============================] - 76s 2s/step - loss: 0.5512 - binary_accuracy: 0.9329 - val_loss: 0.5580 - val_binary_accuracy: 0.9183 - lr: 0.0010
# Epoch 13/50
# 33/33 [==============================] - ETA: 0s - loss: 0.5278 - binary_accuracy: 0.9296
# Epoch 13: val_binary_accuracy did not improve from 0.91825
# 33/33 [==============================] - 75s 2s/step - loss: 0.5278 - binary_accuracy: 0.9296 - val_loss: 0.6233 - val_binary_accuracy: 0.8745 - lr: 0.0010
# Epoch 14/50
# 33/33 [==============================] - ETA: 0s - loss: 0.4830 - binary_accuracy: 0.9422
# Epoch 14: val_binary_accuracy did not improve from 0.91825
# 33/33 [==============================] - 75s 2s/step - loss: 0.4830 - binary_accuracy: 0.9422 - val_loss: 0.5487 - val_binary_accuracy: 0.9002 - lr: 0.0010
# Epoch 15/50
# 33/33 [==============================] - ETA: 0s - loss: 0.4745 - binary_accuracy: 0.9263
# Epoch 15: val_binary_accuracy improved from 0.91825 to 0.93061, saving model to best_model.h5
# 33/33 [==============================] - 76s 2s/step - loss: 0.4745 - binary_accuracy: 0.9263 - val_loss: 0.4477 - val_binary_accuracy: 0.9306 - lr: 0.0010
# Epoch 16/50
# 33/33 [==============================] - ETA: 0s - loss: 0.4422 - binary_accuracy: 0.9327
# Epoch 16: val_binary_accuracy did not improve from 0.93061
# 33/33 [==============================] - 75s 2s/step - loss: 0.4422 - binary_accuracy: 0.9327 - val_loss: 0.5658 - val_binary_accuracy: 0.8707 - lr: 0.0010
# Epoch 17/50
# 33/33 [==============================] - ETA: 0s - loss: 0.4248 - binary_accuracy: 0.9320
# Epoch 17: val_binary_accuracy did not improve from 0.93061
# 33/33 [==============================] - 75s 2s/step - loss: 0.4248 - binary_accuracy: 0.9320 - val_loss: 0.4329 - val_binary_accuracy: 0.9240 - lr: 0.0010
# Epoch 18/50
# 33/33 [==============================] - ETA: 0s - loss: 0.3979 - binary_accuracy: 0.9408
# Epoch 18: val_binary_accuracy did not improve from 0.93061
# 33/33 [==============================] - 75s 2s/step - loss: 0.3979 - binary_accuracy: 0.9408 - val_loss: 0.4225 - val_binary_accuracy: 0.9221 - lr: 0.0010
# Epoch 19/50
# 33/33 [==============================] - ETA: 0s - loss: 0.3848 - binary_accuracy: 0.9401
# Epoch 19: val_binary_accuracy did not improve from 0.93061
# 33/33 [==============================] - 75s 2s/step - loss: 0.3848 - binary_accuracy: 0.9401 - val_loss: 0.4737 - val_binary_accuracy: 0.8888 - lr: 0.0010
# Epoch 20/50
# 33/33 [==============================] - ETA: 0s - loss: 0.3822 - binary_accuracy: 0.9310
# Epoch 20: val_binary_accuracy did not improve from 0.93061
# 33/33 [==============================] - 75s 2s/step - loss: 0.3822 - binary_accuracy: 0.9310 - val_loss: 0.3738 - val_binary_accuracy: 0.9287 - lr: 0.0010
# Epoch 21/50
# 33/33 [==============================] - ETA: 0s - loss: 0.3672 - binary_accuracy: 0.9265
# Epoch 21: val_binary_accuracy did not improve from 0.93061
# 33/33 [==============================] - 76s 2s/step - loss: 0.3672 - binary_accuracy: 0.9265 - val_loss: 0.3730 - val_binary_accuracy: 0.9240 - lr: 0.0010
# Epoch 22/50
# 33/33 [==============================] - ETA: 0s - loss: 0.3475 - binary_accuracy: 0.9355
# Epoch 22: val_binary_accuracy improved from 0.93061 to 0.94011, saving model to best_model.h5
# 33/33 [==============================] - 76s 2s/step - loss: 0.3475 - binary_accuracy: 0.9355 - val_loss: 0.3236 - val_binary_accuracy: 0.9401 - lr: 0.0010
# Epoch 23/50
# 33/33 [==============================] - ETA: 0s - loss: 0.3327 - binary_accuracy: 0.9384
# Epoch 23: val_binary_accuracy did not improve from 0.94011
# 33/33 [==============================] - 75s 2s/step - loss: 0.3327 - binary_accuracy: 0.9384 - val_loss: 0.5050 - val_binary_accuracy: 0.8603 - lr: 0.0010
# Epoch 24/50
# 33/33 [==============================] - ETA: 0s - loss: 0.3378 - binary_accuracy: 0.9327
# Epoch 24: val_binary_accuracy did not improve from 0.94011
# 33/33 [==============================] - 75s 2s/step - loss: 0.3378 - binary_accuracy: 0.9327 - val_loss: 0.3621 - val_binary_accuracy: 0.9135 - lr: 0.0010
# Epoch 25/50
# 33/33 [==============================] - ETA: 0s - loss: 0.3162 - binary_accuracy: 0.9370
# Epoch 25: val_binary_accuracy did not improve from 0.94011
# 33/33 [==============================] - 76s 2s/step - loss: 0.3162 - binary_accuracy: 0.9370 - val_loss: 0.3091 - val_binary_accuracy: 0.9335 - lr: 0.0010
# Epoch 26/50
# 33/33 [==============================] - ETA: 0s - loss: 0.3049 - binary_accuracy: 0.9396
# Epoch 26: val_binary_accuracy did not improve from 0.94011
# 33/33 [==============================] - 80s 2s/step - loss: 0.3049 - binary_accuracy: 0.9396 - val_loss: 0.3166 - val_binary_accuracy: 0.9249 - lr: 0.0010
# Epoch 27/50
# 33/33 [==============================] - ETA: 0s - loss: 0.2961 - binary_accuracy: 0.9365
# Epoch 27: val_binary_accuracy did not improve from 0.94011
# 33/33 [==============================] - 82s 2s/step - loss: 0.2961 - binary_accuracy: 0.9365 - val_loss: 0.4002 - val_binary_accuracy: 0.8869 - lr: 0.0010
# Epoch 28/50
# 33/33 [==============================] - ETA: 0s - loss: 0.2892 - binary_accuracy: 0.9384
# Epoch 28: val_binary_accuracy did not improve from 0.94011
# 33/33 [==============================] - 81s 2s/step - loss: 0.2892 - binary_accuracy: 0.9384 - val_loss: 0.3513 - val_binary_accuracy: 0.9078 - lr: 0.0010
# Epoch 29/50
# 33/33 [==============================] - ETA: 0s - loss: 0.2695 - binary_accuracy: 0.9451
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 29: val_binary_accuracy did not improve from 0.94011
# 33/33 [==============================] - 80s 2s/step - loss: 0.2695 - binary_accuracy: 0.9451 - val_loss: 0.3752 - val_binary_accuracy: 0.8888 - lr: 0.0010
# Epoch 30/50
# 33/33 [==============================] - ETA: 0s - loss: 0.2822 - binary_accuracy: 0.9348
# Epoch 30: val_binary_accuracy did not improve from 0.94011
# 33/33 [==============================] - 81s 2s/step - loss: 0.2822 - binary_accuracy: 0.9348 - val_loss: 0.4106 - val_binary_accuracy: 0.8736 - lr: 5.0000e-04
# Epoch 31/50
# 33/33 [==============================] - ETA: 0s - loss: 0.2588 - binary_accuracy: 0.9448
# Epoch 31: val_binary_accuracy did not improve from 0.94011
# 33/33 [==============================] - 83s 3s/step - loss: 0.2588 - binary_accuracy: 0.9448 - val_loss: 0.2971 - val_binary_accuracy: 0.9221 - lr: 5.0000e-04
# Epoch 32/50
# 33/33 [==============================] - ETA: 0s - loss: 0.2650 - binary_accuracy: 0.9405
# Epoch 32: val_binary_accuracy did not improve from 0.94011
# 33/33 [==============================] - 86s 3s/step - loss: 0.2650 - binary_accuracy: 0.9405 - val_loss: 0.3066 - val_binary_accuracy: 0.9173 - lr: 5.0000e-04
# Epoch 33/50
# 33/33 [==============================] - ETA: 0s - loss: 0.2606 - binary_accuracy: 0.9412
# Epoch 33: val_binary_accuracy did not improve from 0.94011
# 33/33 [==============================] - 77s 2s/step - loss: 0.2606 - binary_accuracy: 0.9412 - val_loss: 0.3726 - val_binary_accuracy: 0.8831 - lr: 5.0000e-04
# Epoch 34/50
# 33/33 [==============================] - ETA: 0s - loss: 0.2510 - binary_accuracy: 0.9436
# Epoch 34: val_binary_accuracy did not improve from 0.94011
# 33/33 [==============================] - 75s 2s/step - loss: 0.2510 - binary_accuracy: 0.9436 - val_loss: 0.3867 - val_binary_accuracy: 0.8802 - lr: 5.0000e-04
# Epoch 35/50
# 33/33 [==============================] - ETA: 0s - loss: 0.2451 - binary_accuracy: 0.9439
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 35: val_binary_accuracy did not improve from 0.94011
# 33/33 [==============================] - 75s 2s/step - loss: 0.2451 - binary_accuracy: 0.9439 - val_loss: 0.3800 - val_binary_accuracy: 0.8812 - lr: 5.0000e-04
# Epoch 36/50
# 33/33 [==============================] - ETA: 0s - loss: 0.2430 - binary_accuracy: 0.9451
# Epoch 36: val_binary_accuracy did not improve from 0.94011
# 33/33 [==============================] - 75s 2s/step - loss: 0.2430 - binary_accuracy: 0.9451 - val_loss: 0.3654 - val_binary_accuracy: 0.8859 - lr: 2.5000e-04
# Epoch 37/50
# 33/33 [==============================] - ETA: 0s - loss: 0.2414 - binary_accuracy: 0.9405
# Epoch 37: val_binary_accuracy did not improve from 0.94011
# 33/33 [==============================] - 75s 2s/step - loss: 0.2414 - binary_accuracy: 0.9405 - val_loss: 0.3418 - val_binary_accuracy: 0.8935 - lr: 2.5000e-04
# Epoch 38/50
# 33/33 [==============================] - ETA: 0s - loss: 0.2414 - binary_accuracy: 0.9462
# Epoch 38: val_binary_accuracy did not improve from 0.94011
# 33/33 [==============================] - 75s 2s/step - loss: 0.2414 - binary_accuracy: 0.9462 - val_loss: 0.3758 - val_binary_accuracy: 0.8812 - lr: 2.5000e-04
# Epoch 39/50
# 33/33 [==============================] - ETA: 0s - loss: 0.2442 - binary_accuracy: 0.9417
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 39: val_binary_accuracy did not improve from 0.94011
# 33/33 [==============================] - 75s 2s/step - loss: 0.2442 - binary_accuracy: 0.9417 - val_loss: 0.3665 - val_binary_accuracy: 0.8840 - lr: 2.5000e-04
# Epoch 40/50
# 33/33 [==============================] - ETA: 0s - loss: 0.2414 - binary_accuracy: 0.9417
# Epoch 40: val_binary_accuracy did not improve from 0.94011
# 33/33 [==============================] - 74s 2s/step - loss: 0.2414 - binary_accuracy: 0.9417 - val_loss: 0.3723 - val_binary_accuracy: 0.8812 - lr: 1.2500e-04
# Epoch 41/50
# 33/33 [==============================] - ETA: 0s - loss: 0.2385 - binary_accuracy: 0.9462Restoring model weights from the end of the best epoch: 31.
#
# Epoch 41: val_binary_accuracy did not improve from 0.94011
# 33/33 [==============================] - 75s 2s/step - loss: 0.2385 - binary_accuracy: 0.9462 - val_loss: 0.4012 - val_binary_accuracy: 0.8745 - lr: 1.2500e-04
# Epoch 41: early stopping

# %%
test_loss, test_acc = model.evaluate(val_generator)
print(f'Test accuracy: {test_acc}')
# Out:
# 9/9 [==============================] - 9s 952ms/step - loss: 0.2971 - binary_accuracy: 0.9221
# Test accuracy: 0.9220532178878784

# %%
hist_= pd.DataFrame(hist.history)
hist_
# Out:
#         loss  binary_accuracy  val_loss  val_binary_accuracy        lr
# 0   3.224909         0.793530  2.051356             0.835551  0.001000
# 1   1.634081         0.871075  1.394444             0.877376  0.001000
# 2   1.242862         0.901760  1.158241             0.893536  0.001000
# 3   1.088902         0.904853  1.071698             0.876426  0.001000
# 4   0.963436         0.910561  0.956413             0.885932  0.001000
# 5   0.871203         0.918411  0.917475             0.873574  0.001000
# 6   0.790616         0.925309  0.808201             0.893536  0.001000
# 7   0.720559         0.931970  0.756465             0.890684  0.001000
# 8   0.676813         0.926499  0.676779             0.913498  0.001000
# 9   0.627585         0.927688  0.674429             0.894487  0.001000
# 10  0.590520         0.926736  0.695404             0.869772  0.001000
# 11  0.551249         0.932921  0.558006             0.918251  0.001000
# 12  0.527806         0.929591  0.623291             0.874525  0.001000
# 13  0.482972         0.942198  0.548701             0.900190  0.001000
# 14  0.474526         0.926261  0.447729             0.930608  0.001000
# 15  0.442241         0.932683  0.565806             0.870722  0.001000
# 16  0.424769         0.931970  0.432874             0.923954  0.001000
# 17  0.397905         0.940771  0.422477             0.922053  0.001000
# 18  0.384846         0.940057  0.473691             0.888783  0.001000
# 19  0.382157         0.931018  0.373756             0.928707  0.001000
# 20  0.367221         0.926499  0.373022             0.923954  0.001000
# 21  0.347516         0.935538  0.323608             0.940114  0.001000
# 22  0.332668         0.938392  0.504981             0.860266  0.001000
# 23  0.337839         0.932683  0.362086             0.913498  0.001000
# 24  0.316249         0.936965  0.309148             0.933460  0.001000
# 25  0.304946         0.939581  0.316576             0.924905  0.001000
# 26  0.296059         0.936489  0.400248             0.886882  0.001000
# 27  0.289228         0.938392  0.351264             0.907795  0.001000
# 28  0.269488         0.945052  0.375152             0.888783  0.001000
# 29  0.282180         0.934824  0.410637             0.873574  0.000500
# 30  0.258810         0.944814  0.297149             0.922053  0.000500
# 31  0.264985         0.940533  0.306624             0.917300  0.000500
# 32  0.260629         0.941246  0.372642             0.883080  0.000500
# 33  0.251035         0.943625  0.386732             0.880228  0.000500
# 34  0.245105         0.943863  0.379952             0.881179  0.000500
# 35  0.243020         0.945052  0.365443             0.885932  0.000250
# 36  0.241412         0.940533  0.341767             0.893536  0.000250
# 37  0.241430         0.946242  0.375796             0.881179  0.000250
# 38  0.244157         0.941722  0.366458             0.884030  0.000250
# 39  0.241433         0.941722  0.372338             0.881179  0.000125
# 40  0.238513         0.946242  0.401176             0.874525  0.000125

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(hist_['loss'],label='Train_Loss')
plt.plot(hist_['val_loss'],label='Validation_Loss')
plt.title('Grafik Loss',fontsize=20)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.subplot(1,2,2)
plt.plot(hist_['binary_accuracy'],label='Train_Accuracy')
plt.plot(hist_['val_binary_accuracy'],label='Validation_Accuracy')
plt.title('Grafik Accuracy',fontsize=20)
plt.xlabel("Epoch")
plt.ylabel("Akurasi")
plt.legend()

# %%
test_generator = valid_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 600 images belonging to 2 classes.

# %%
y_pred = model.predict(test_generator)
# Out:
# 5/5 [==============================] - 10s 1s/step

# %%
y_pred_binary = (y_pred > 0.5).astype(int)
y_true = test_generator.classes

# %%
classification_rep = classification_report(y_true, y_pred_binary, target_names=['Normal', 'Pneumonia'])
confusion_mat = confusion_matrix(y_true, y_pred_binary)

print("Classification Report:\n", classification_rep)
print("\nConfusion Matrix:\n", confusion_mat)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.92      0.99      0.95       300
#    Pneumonia       0.99      0.91      0.95       300
#
#     accuracy                           0.95       600
#    macro avg       0.95      0.95      0.95       600
# weighted avg       0.95      0.95      0.95       600
#
#
# Confusion Matrix:
#  [[297   3]
#  [ 27 273]]

# %%
plt.figure(figsize=(3, 2))
sns.set(font_scale=0.8)
sns.heatmap(confusion_mat, annot=True, cmap='viridis', cbar=False, fmt='d', 
            xticklabels=['Normal', 'Pneumonia'], yticklabels=['Normal', 'Pneumonia'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
model.save('pneumonia_densenet201v2.h5')

# %%
# uploaded = files.upload()

# for fn in uploaded.keys():
#   path = fn
img = image.load_img('chest/val/PNEUMONIA/person74_virus_135.jpeg', target_size=(224,224,3))

imgplot = plt.imshow(img)
plt.axis('off')
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
images = np.vstack([x])

classes = model.predict(images)
print('chest_xray/val/PNEUMONIA/person1005_virus_1688.jpeg')
if classes[0] > 0.5:
  print('Image classified as Pneumonia')
else:
  print('Image classified as Normal')
print(classes[0])
# Out:
# 1/1 [==============================] - 4s 4s/step
# chest_xray/val/PNEUMONIA/person1005_virus_1688.jpeg
# Image classified as Pneumonia
# [0.9863094]
