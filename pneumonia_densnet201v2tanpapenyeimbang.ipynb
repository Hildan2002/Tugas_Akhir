# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, regularizers
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.densenet import DenseNet201, preprocess_input
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.utils import class_weight

from sklearn.metrics import classification_report, confusion_matrix
import zipfile, os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report


print(tf.__version__)
# Out:
# 2.10.1

# %%
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    print("Available GPUs:", len(gpus))
else:
    print("No GPUs available.")
# Out:
# Available GPUs: 1

# %%
base_dir = 'chest'
train_dir = 'chest/train'
test_dir = 'chest/test'
val_dir = 'chest/val'
os.listdir(base_dir)
# Out:
# ['test', 'train', 'val']

# %%
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

# Function to preview images directly from a directory
def preview_images_from_directory(directory, class_labels, num_images=5):
    class_names = os.listdir(directory)

    plt.figure(figsize=(15, 3))
    for class_name in class_names:
        class_path = os.path.join(directory, class_name)
        image_files = [f for f in os.listdir(class_path) if f.endswith('.jpeg')]
        selected_images = random.sample(image_files, min(num_images, len(image_files)))

        for i, image_file in enumerate(selected_images):
            plt.subplot(len(class_names), num_images, len(class_names) * i + class_names.index(class_name) + 1)
            img_path = os.path.join(class_path, image_file)
            img = mpimg.imread(img_path)
            plt.imshow(img)
            plt.title(f"Label: {class_labels[class_names.index(class_name)]}")
            plt.axis('off')

    plt.show()

# Define class labels for binary classification
class_labels_binary = ["Normal", "Pneumonia"]

# Preview images from the training directory
print("Preview of Training Images:")
preview_images_from_directory(train_dir, class_labels_binary)

# Preview images from the validation directory
print("Preview of Validation Images:")
preview_images_from_directory(val_dir, class_labels_binary)
# Out:
# Preview of Training Images:
# Preview of Validation Images:

# %%
img_width, img_height = 224, 224
batch_size = 128

datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    shear_range=0.2,
    zoom_range=0.2,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
)

train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
)

valid_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

val_generator = valid_datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
)
# Out:
# Found 4204 images belonging to 2 classes.
# Found 1052 images belonging to 2 classes.

# %%
# Function to preview images from a data generator with class labels
def preview_images(generator, class_labels, num_images=5):
    # Get a batch of images and labels from the generator
    images, labels = next(generator)

    # Map numeric labels to class names
    class_names = [class_labels[int(label)] for label in labels]

    # Display the images with labels
    plt.figure(figsize=(15, 3))
    for i in range(num_images):
        plt.subplot(1, num_images, i+1)
        plt.imshow(images[i])
        plt.title(f"Label: {class_names[i]}")
        plt.axis('off')
    plt.show()

# Define class labels for binary classification
class_labels_binary = ["Normal", "Pneumonia"]

# Preview images from the training generator
print("Preview of Training Images:")
preview_images(train_generator, class_labels_binary)

# Preview images from the validation generator
print("Preview of Validation Images:")
preview_images(val_generator, class_labels_binary)
# Out:
# Preview of Training Images:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Preview of Validation Images:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Display the number of samples in each set
print("Number of samples in training set:", len(train_generator.classes))
print("Number of samples in validation set:", len(val_generator.classes))

# Visualize the number of samples in each set with a bar chart
sets = ['Training', 'Validation']
counts = [len(train_generator.classes), len(val_generator.classes)]

plt.bar(sets, counts, color=['blue', 'orange'])
plt.xlabel('Data Sets')
plt.ylabel('Number of Samples')
plt.title('Number of Samples in Each Data Set')
plt.show()
# Out:
# Number of samples in training set: 4204
# Number of samples in validation set: 1052

# %%
# Display the number of samples in each class within the training set
train_class_counts = np.bincount(train_generator.classes)
train_class_labels = ['Normal', 'Pneumonia']

plt.bar(train_class_labels, train_class_counts[:len(train_class_labels)], color=['skyblue', 'navy'])
plt.xlabel('Class Labels')
plt.ylabel('Number of Samples')
plt.title('Number of Samples in Each Class (Training Set)')
plt.show()

# Display the number of samples in each class within the validation set
val_class_counts = np.bincount(val_generator.classes)
val_class_labels = ['Normal', 'Pneumonia']

plt.bar(val_class_labels, val_class_counts[:len(val_class_labels)], color=['lightcoral', 'darkred'])
plt.xlabel('Class Labels')
plt.ylabel('Number of Samples')
plt.title('Number of Samples in Each Class (Validation Set)')
plt.show()

# %%
class_weights = class_weight.compute_class_weight('balanced', classes = np.unique(train_generator.classes), y = train_generator.classes)

class_weight_dict = dict(enumerate(class_weights))

class_weight_dict
# Out:
# {0: 2.0487329434697856, 1: 0.6614222781623663}

# %%
densenet201 = DenseNet201(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet'
)

for layer in densenet201.layers:
    layer.trainable = False

x = densenet201.output
x = layers.GlobalAveragePooling2D()(x)
# x = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.4)(x)
pred = layers.Dense(1, activation='sigmoid')(x)

model = Model(inputs=densenet201.input, outputs=pred)

model.compile(optimizer=tf.keras.optimizers.Adamax(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['binary_accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, min_lr=1e-5, verbose=1)

model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_binary_accuracy', save_best_only=True, mode='max', verbose=1)

# %%
epochs=50

hist = model.fit(train_generator,
                 epochs=epochs,
                 validation_data=val_generator,
                 callbacks=[early_stopping, reduce_lr, model_checkpoint],
                 # class_weight=class_weight_dict
)
# Out:
# Epoch 1/50
# 33/33 [==============================] - ETA: 0s - loss: 0.2961 - binary_accuracy: 0.8754
# Epoch 1: val_binary_accuracy improved from -inf to 0.92205, saving model to best_model.h5
# 33/33 [==============================] - 128s 3s/step - loss: 0.2961 - binary_accuracy: 0.8754 - val_loss: 0.2014 - val_binary_accuracy: 0.9221 - lr: 0.0010
# Epoch 2/50
# 33/33 [==============================] - ETA: 0s - loss: 0.2109 - binary_accuracy: 0.9186
# Epoch 2: val_binary_accuracy improved from 0.92205 to 0.93061, saving model to best_model.h5
# 33/33 [==============================] - 88s 3s/step - loss: 0.2109 - binary_accuracy: 0.9186 - val_loss: 0.1737 - val_binary_accuracy: 0.9306 - lr: 0.0010
# Epoch 3/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1926 - binary_accuracy: 0.9277
# Epoch 3: val_binary_accuracy improved from 0.93061 to 0.93441, saving model to best_model.h5
# 33/33 [==============================] - 84s 3s/step - loss: 0.1926 - binary_accuracy: 0.9277 - val_loss: 0.1684 - val_binary_accuracy: 0.9344 - lr: 0.0010
# Epoch 4/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1723 - binary_accuracy: 0.9320
# Epoch 4: val_binary_accuracy did not improve from 0.93441
# 33/33 [==============================] - 84s 3s/step - loss: 0.1723 - binary_accuracy: 0.9320 - val_loss: 0.2151 - val_binary_accuracy: 0.9087 - lr: 0.0010
# Epoch 5/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1706 - binary_accuracy: 0.9327
# Epoch 5: val_binary_accuracy did not improve from 0.93441
# 33/33 [==============================] - 78s 2s/step - loss: 0.1706 - binary_accuracy: 0.9327 - val_loss: 0.1711 - val_binary_accuracy: 0.9316 - lr: 0.0010
# Epoch 6/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1639 - binary_accuracy: 0.9346
# Epoch 6: val_binary_accuracy improved from 0.93441 to 0.94867, saving model to best_model.h5
# 33/33 [==============================] - 85s 3s/step - loss: 0.1639 - binary_accuracy: 0.9346 - val_loss: 0.1342 - val_binary_accuracy: 0.9487 - lr: 0.0010
# Epoch 7/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1531 - binary_accuracy: 0.9427
# Epoch 7: val_binary_accuracy did not improve from 0.94867
# 33/33 [==============================] - 76s 2s/step - loss: 0.1531 - binary_accuracy: 0.9427 - val_loss: 0.1521 - val_binary_accuracy: 0.9373 - lr: 0.0010
# Epoch 8/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1584 - binary_accuracy: 0.9405
# Epoch 8: val_binary_accuracy did not improve from 0.94867
# 33/33 [==============================] - 70s 2s/step - loss: 0.1584 - binary_accuracy: 0.9405 - val_loss: 0.1461 - val_binary_accuracy: 0.9401 - lr: 0.0010
# Epoch 9/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1412 - binary_accuracy: 0.9462
# Epoch 9: val_binary_accuracy did not improve from 0.94867
# 33/33 [==============================] - 73s 2s/step - loss: 0.1412 - binary_accuracy: 0.9462 - val_loss: 0.1686 - val_binary_accuracy: 0.9325 - lr: 0.0010
# Epoch 10/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1335 - binary_accuracy: 0.9515
# Epoch 10: val_binary_accuracy improved from 0.94867 to 0.95152, saving model to best_model.h5
# 33/33 [==============================] - 76s 2s/step - loss: 0.1335 - binary_accuracy: 0.9515 - val_loss: 0.1290 - val_binary_accuracy: 0.9515 - lr: 0.0010
# Epoch 11/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1397 - binary_accuracy: 0.9489
# Epoch 11: val_binary_accuracy did not improve from 0.95152
# 33/33 [==============================] - 80s 2s/step - loss: 0.1397 - binary_accuracy: 0.9489 - val_loss: 0.1700 - val_binary_accuracy: 0.9335 - lr: 0.0010
# Epoch 12/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1373 - binary_accuracy: 0.9451
# Epoch 12: val_binary_accuracy improved from 0.95152 to 0.95437, saving model to best_model.h5
# 33/33 [==============================] - 73s 2s/step - loss: 0.1373 - binary_accuracy: 0.9451 - val_loss: 0.1122 - val_binary_accuracy: 0.9544 - lr: 0.0010
# Epoch 13/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1369 - binary_accuracy: 0.9500
# Epoch 13: val_binary_accuracy did not improve from 0.95437
# 33/33 [==============================] - 70s 2s/step - loss: 0.1369 - binary_accuracy: 0.9500 - val_loss: 0.1640 - val_binary_accuracy: 0.9316 - lr: 0.0010
# Epoch 14/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1307 - binary_accuracy: 0.9527
# Epoch 14: val_binary_accuracy did not improve from 0.95437
# 33/33 [==============================] - 69s 2s/step - loss: 0.1307 - binary_accuracy: 0.9527 - val_loss: 0.1556 - val_binary_accuracy: 0.9363 - lr: 0.0010
# Epoch 15/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1268 - binary_accuracy: 0.9524
# Epoch 15: val_binary_accuracy did not improve from 0.95437
# 33/33 [==============================] - 73s 2s/step - loss: 0.1268 - binary_accuracy: 0.9524 - val_loss: 0.1657 - val_binary_accuracy: 0.9316 - lr: 0.0010
# Epoch 16/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1311 - binary_accuracy: 0.9517
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 16: val_binary_accuracy did not improve from 0.95437
# 33/33 [==============================] - 69s 2s/step - loss: 0.1311 - binary_accuracy: 0.9517 - val_loss: 0.1388 - val_binary_accuracy: 0.9430 - lr: 0.0010
# Epoch 17/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1259 - binary_accuracy: 0.9522
# Epoch 17: val_binary_accuracy did not improve from 0.95437
# 33/33 [==============================] - 68s 2s/step - loss: 0.1259 - binary_accuracy: 0.9522 - val_loss: 0.1983 - val_binary_accuracy: 0.9211 - lr: 5.0000e-04
# Epoch 18/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1151 - binary_accuracy: 0.9591
# Epoch 18: val_binary_accuracy did not improve from 0.95437
# 33/33 [==============================] - 68s 2s/step - loss: 0.1151 - binary_accuracy: 0.9591 - val_loss: 0.1342 - val_binary_accuracy: 0.9468 - lr: 5.0000e-04
# Epoch 19/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1214 - binary_accuracy: 0.9555
# Epoch 19: val_binary_accuracy did not improve from 0.95437
# 33/33 [==============================] - 68s 2s/step - loss: 0.1214 - binary_accuracy: 0.9555 - val_loss: 0.1514 - val_binary_accuracy: 0.9373 - lr: 5.0000e-04
# Epoch 20/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1251 - binary_accuracy: 0.9555
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 20: val_binary_accuracy did not improve from 0.95437
# 33/33 [==============================] - 69s 2s/step - loss: 0.1251 - binary_accuracy: 0.9555 - val_loss: 0.1410 - val_binary_accuracy: 0.9439 - lr: 5.0000e-04
# Epoch 21/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1164 - binary_accuracy: 0.9569
# Epoch 21: val_binary_accuracy did not improve from 0.95437
# 33/33 [==============================] - 69s 2s/step - loss: 0.1164 - binary_accuracy: 0.9569 - val_loss: 0.1447 - val_binary_accuracy: 0.9420 - lr: 2.5000e-04
# Epoch 22/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1172 - binary_accuracy: 0.9586Restoring model weights from the end of the best epoch: 12.
#
# Epoch 22: val_binary_accuracy did not improve from 0.95437
# 33/33 [==============================] - 69s 2s/step - loss: 0.1172 - binary_accuracy: 0.9586 - val_loss: 0.1657 - val_binary_accuracy: 0.9344 - lr: 2.5000e-04
# Epoch 22: early stopping

# %%
test_loss, test_acc = model.evaluate(val_generator)
print(f'Test accuracy: {test_acc}')
# Out:
# 9/9 [==============================] - 9s 896ms/step - loss: 0.1122 - binary_accuracy: 0.9544
# Test accuracy: 0.9543726444244385

# %%
hist_= pd.DataFrame(hist.history)
hist_
# Out:
#         loss  binary_accuracy  val_loss  val_binary_accuracy       lr
# 0   0.296082         0.875357  0.201443             0.922053  0.00100
# 1   0.210883         0.918649  0.173694             0.930608  0.00100
# 2   0.192570         0.927688  0.168446             0.934411  0.00100
# 3   0.172268         0.931970  0.215064             0.908745  0.00100
# 4   0.170594         0.932683  0.171050             0.931559  0.00100
# 5   0.163916         0.934586  0.134168             0.948669  0.00100
# 6   0.153082         0.942674  0.152123             0.937262  0.00100
# 7   0.158366         0.940533  0.146130             0.940114  0.00100
# 8   0.141236         0.946242  0.168613             0.932509  0.00100
# 9   0.133523         0.951475  0.128969             0.951521  0.00100
# 10  0.139716         0.948858  0.170015             0.933460  0.00100
# 11  0.137304         0.945052  0.112227             0.954373  0.00100
# 12  0.136861         0.950048  0.163975             0.931559  0.00100
# 13  0.130682         0.952664  0.155625             0.936312  0.00100
# 14  0.126824         0.952426  0.165708             0.931559  0.00100
# 15  0.131067         0.951713  0.138814             0.942966  0.00100
# 16  0.125862         0.952188  0.198340             0.921103  0.00050
# 17  0.115117         0.959087  0.134209             0.946768  0.00050
# 18  0.121361         0.955519  0.151428             0.937262  0.00050
# 19  0.125078         0.955519  0.140963             0.943916  0.00050
# 20  0.116385         0.956946  0.144723             0.942015  0.00025
# 21  0.117174         0.958611  0.165671             0.934411  0.00025

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(hist_['loss'],label='Train_Loss')
plt.plot(hist_['val_loss'],label='Validation_Loss')
plt.title('Train_Loss & Validation_Loss',fontsize=20)
plt.legend()
plt.subplot(1,2,2)
plt.plot(hist_['binary_accuracy'],label='Train_Accuracy')
plt.plot(hist_['val_binary_accuracy'],label='Validation_Accuracy')
plt.title('Train_Accuracy & Validation_Accuracy',fontsize=20)
plt.legend()

# %%
test_generator = valid_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 600 images belonging to 2 classes.

# %%
y_pred = model.predict(test_generator)
# Out:
# 5/5 [==============================] - 15s 2s/step

# %%
y_pred_binary = (y_pred > 0.5).astype(int)
y_true = test_generator.classes

# %%
classification_rep = classification_report(y_true, y_pred_binary, target_names=['Normal', 'Pneumonia'])
confusion_mat = confusion_matrix(y_true, y_pred_binary)

print("Classification Report:\n", classification_rep)
print("\nConfusion Matrix:\n", confusion_mat)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.96      0.95      0.95       300
#    Pneumonia       0.95      0.96      0.96       300
#
#     accuracy                           0.95       600
#    macro avg       0.96      0.95      0.95       600
# weighted avg       0.96      0.95      0.95       600
#
#
# Confusion Matrix:
#  [[285  15]
#  [ 12 288]]

# %%
plt.figure(figsize=(3, 2))
sns.set(font_scale=0.8)
sns.heatmap(confusion_mat, annot=True, cmap='viridis', cbar=False, fmt='d', 
            xticklabels=['Normal', 'Pneumonia'], yticklabels=['Normal', 'Pneumonia'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
model.save('pneumonia_densenet201v2.h5')

# %%
# uploaded = files.upload()

# for fn in uploaded.keys():
#   path = fn
img = image.load_img('chest/val/PNEUMONIA/person74_virus_135.jpeg', target_size=(224,224,3))

imgplot = plt.imshow(img)
plt.axis('off')
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
images = np.vstack([x])

classes = model.predict(images)
print('chest_xray/val/PNEUMONIA/person1005_virus_1688.jpeg')
if classes[0] > 0.5:
  print('Image classified as Pneumonia')
else:
  print('Image classified as Normal')
print(classes[0])
# Out:
# 1/1 [==============================] - 5s 5s/step
# chest_xray/val/PNEUMONIA/person1005_virus_1688.jpeg
# Image classified as Pneumonia
# [0.99617356]
